# %%
from typing_extensions import TypedDict

class State(TypedDict):
    graph_info: str

# %%
def start_play(state:State):
    print("Start Play node has been called")
    return {'graph_info':state["graph_info"]+" I am planning to play"}

def cricket(state:State):
    print("Cricket Node has been called")
    return {"graph_info":state["graph_info"]+" Cricket"}

def badminton(state:State):
    print("My badminton node has been called")
    return {"graph_info":state['graph_info']+" Badminton"}

# %%
import random
from typing import Literal

def random_play(state:State)-> Literal['cricket','badminton']:
    if random.random()>0.5:
        return "cricket"
    else:
        return "badminton"

# %%
from IPython.display import Image,display
from langgraph.graph import StateGraph,START,END

## Build Graph
graph= StateGraph(State)

## add all the nodes
graph.add_node("start_play",start_play)

graph.add_node("cricket",cricket)
graph.add_node("badminton",badminton)

graph.add_edge(START,"start_play")
graph.add_conditional_edges("start_play",random_play)
graph.add_edge("cricket",END)
graph.add_edge("badminton",END)

graph_builder = graph.compile()

from IPython.display import Markdown, display

mermaid_code = graph_builder.get_graph().draw_mermaid()
display(Markdown(f"```mermaid\n{mermaid_code}\n```"))
# Out:
# ```mermaid
# %%{init: {'flowchart': {'curve': 'linear'}}}%%
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	__end__([<p>__end__</p>]):::last
# 	start_play(start_play)
# 	cricket(cricket)
# 	badminton(badminton)
# 	__start__ --> start_play;
# 	badminton --> __end__;
# 	cricket --> __end__;
# 	start_play -.-> cricket;
# 	start_play -.-> badminton;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
#
# ```

# %%
with open("my_graph.mmd", "w") as f:
    f.write(mermaid_code)

# %%
graph_viz = graph_builder.get_graph().to_graphviz()
graph_viz.render(filename="my_graph", format="png", cleanup=True)

# ----------------------------
# 5️⃣ Display PNG in Notebook
# ----------------------------
display(Image(filename="my_graph.png"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 graph_viz = graph_builder.get_graph().to_graphviz()
#       2 graph_viz.render(filename="my_graph", format="png", cleanup=True)
#       4 # ----------------------------
#       5 # 5️⃣ Display PNG in Notebook
#       6 # ----------------------------
#
# AttributeError: 'DrawableGraph' object has no attribute 'to_graphviz'

# %%
pip install graphviz
# Out:
# ...
#      ---------------------------------------- 0.0/47.3 kB ? eta -:--:--
#      ---------------------------------------- 47.3/47.3 kB 2.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START, END
from langgraph.graph.drawable import DrawableGraph

# 1️⃣ Build the graph
graph = StateGraph(State)

graph.add_node("start_play", start_play)
graph.add_node("cricket", cricket)
graph.add_node("badminton", badminton)

graph.add_edge(START, "start_play")
graph.add_conditional_edges("start_play", random_play)
graph.add_edge("cricket", END)
graph.add_edge("badminton", END)

graph_builder = graph.compile()

# 2️⃣ Convert to Graphviz object
graph_viz = graph_builder.get_graph().to_graphviz()

# 3️⃣ Render to PNG
graph_viz.render(filename="my_graph", format="png", cleanup=True)

# 4️⃣ Display PNG in notebook
display(Image(filename="my_graph.png"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 from IPython.display import Image, display
#       2 from langgraph.graph import StateGraph, START, END
# ----> 3 from langgraph.graph.drawable import DrawableGraph
#       5 # 1️⃣ Build the graph
#       6 graph = StateGraph(State)
#
# ModuleNotFoundError: No module named 'langgraph.graph.drawable'

# %%
graph_builder.invoke({"graph_info":"My name is Krish"})
# Out:
# Start Play node has been called
# My badminton node has been called
# {'graph_info': 'My name is Krish I am planning to play Badminton'}

# %%
from langgraph.graph import StateGraph, START, END

print("StateGraph:", StateGraph)
print("START:", START)
print("END:", END)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from langgraph.graph import StateGraph, START, END
#       3 print("StateGraph:", StateGraph)
#       4 print("START:", START)
#
# File c:\anaconda3\envs\myenv\Lib\site-packages\langgraph\graph\__init__.py:1
# ----> 1 from langgraph.graph.graph import END, START, Graph
#       2 from langgraph.graph.message import MessageGraph, MessagesState, add_messages
#       3 from langgraph.graph.state import StateGraph
#
# File c:\anaconda3\envs\myenv\Lib\site-packages\langgraph\graph\graph.py:28
#      23 from langchain_core.runnables.graph import (
#      24     Node as RunnableGraphNode,
#      25 )
#      27 from langgraph.channels.ephemeral_value import EphemeralValue
# ---> 28 from langgraph.checkpoint import BaseCheckpointSaver
#      29 from langgraph.constants import END, START, TAG_HIDDEN, Send
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\anaconda3\envs\myenv\python.exe

# %%
# !pip install -U langgraph langchain langchain-core langchain-community

# %%
pip install -U langgraph langchain langchain-core langchain-community
# Out:
# ...
#   Using cached langchain-1.2.0-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached langchain-1.2.0-py3-none-any.whl (102 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# ...
#
#   Attempting uninstall: langchain-text-splitters
#
#     Found existing installation: langchain-text-splitters 0.2.2
#
#     Uninstalling langchain-text-splitters-0.2.2:
#
#       Successfully uninstalled langchain-text-splitters-0.2.2
#
#   Attempting uninstall: langchain-community
#
#     Found existing installation: langchain-community 0.2.9
#
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#     Uninstalling langchain-community-0.2.9:
# ...
